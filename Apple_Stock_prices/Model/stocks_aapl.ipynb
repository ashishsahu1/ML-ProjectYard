# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### ***MICRO TASK 1***

# %%
df=pd.read_csv('/content/EOD-AAPL.csv')
df
# Out:
#             Date    Open     High  ...    Adj_Low  Adj_Close   Adj_Volume
# 0     2017-12-28  171.00  171.850  ...  41.011877  41.156217   65920748.0
# 1     2017-12-27  170.10  170.780  ...  40.826640  41.040745   85992852.0
# 2     2017-12-26  170.80  171.470  ...  40.819183  41.033528  132742144.0
# 3     2017-12-22  174.68  175.424  ...  41.978957  42.101646   65397776.0
# 4     2017-12-21  174.17  176.020  ...  41.882730  42.101646   83799584.0
# ...          ...     ...      ...  ...        ...        ...          ...
# 1085  2013-09-09  505.00  507.920  ...  15.948451  16.033661  340687200.0
# 1086  2013-09-06  498.44  499.380  ...  15.519869  15.781833  359525600.0
# 1087  2013-09-05  500.25  500.680  ...  15.636755  15.688388  236367600.0
# 1088  2013-09-04  499.56  502.240  ...  15.720381  15.796753  345032800.0
# 1089  2013-09-03  493.10  500.600  ...  15.437510  15.476472  331928800.0
#
# [1090 rows x 13 columns]

# %%
df.describe()
# Out:
#               Open         High  ...    Adj_Close    Adj_Volume
# count  1090.000000  1090.000000  ...  1090.000000  1.090000e+03
# mean    194.564537   196.114735  ...    26.373196  1.931334e+08
# std     160.562848   161.812898  ...     6.616455  1.112891e+08
# min      90.000000    90.700000  ...    14.258197  4.590369e+07
# 25%     108.042500   108.942500  ...    22.201030  1.133450e+08
# 50%     121.585000   122.504950  ...    25.789823  1.681963e+08
# 75%     156.905000   157.809625  ...    29.362853  2.394642e+08
# max     649.900000   651.260000  ...    42.440845  1.065523e+09
#
# [8 rows x 12 columns]

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume        float64
# Dividend      float64
# Split         float64
# Adj_Open      float64
# Adj_High      float64
# Adj_Low       float64
# Adj_Close     float64
# Adj_Volume    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividend', 'Split',
#        'Adj_Open', 'Adj_High', 'Adj_Low', 'Adj_Close', 'Adj_Volume'],
#       dtype='object')

# %%
df['PCT_change']=((df['Adj_Close']-df['Adj_Open'])/df['Adj_Open']*100)
df
# Out:
#             Date    Open     High  ...  Adj_Close   Adj_Volume  PCT_change
# 0     2017-12-28  171.00  171.850  ...  41.156217   65920748.0    0.046784
# 1     2017-12-27  170.10  170.780  ...  41.040745   85992852.0    0.293945
# 2     2017-12-26  170.80  171.470  ...  41.033528  132742144.0   -0.134660
# 3     2017-12-22  174.68  175.424  ...  42.101646   65397776.0    0.188917
# 4     2017-12-21  174.17  176.020  ...  42.101646   83799584.0    0.482287
# ...          ...     ...      ...  ...        ...          ...         ...
# 1085  2013-09-09  505.00  507.920  ...  16.033661  340687200.0    0.231683
# 1086  2013-09-06  498.44  499.380  ...  15.781833  359525600.0   -0.044138
# 1087  2013-09-05  500.25  500.680  ...  15.688388  236367600.0   -0.995502
# 1088  2013-09-04  499.56  502.240  ...  15.796753  345032800.0   -0.173953
# 1089  2013-09-03  493.10  500.600  ...  15.476472  331928800.0   -0.916650
#
# [1090 rows x 14 columns]

# %%
df['HL_PCT']=((df['Adj_High']-df['Adj_Low'])/df['Adj_Close']*100)
df
# Out:
#             Date    Open     High  ...   Adj_Volume  PCT_change    HL_PCT
# 0     2017-12-28  171.00  171.850  ...   65920748.0    0.046784  0.800795
# 1     2017-12-27  170.10  170.780  ...   85992852.0    0.293945  0.627198
# 2     2017-12-26  170.80  171.470  ...  132742144.0   -0.134660  1.050009
# 3     2017-12-22  174.68  175.424  ...   65397776.0    0.188917  0.527970
# 4     2017-12-21  174.17  176.020  ...   83799584.0    0.482287  1.097080
# ...          ...     ...      ...  ...          ...         ...       ...
# 1085  2013-09-09  505.00  507.920  ...  340687200.0    0.231683  0.877176
# 1086  2013-09-06  498.44  499.380  ...  359525600.0   -0.044138  1.892738
# 1087  2013-09-05  500.25  500.680  ...  236367600.0   -0.995502  1.421447
# 1088  2013-09-04  499.56  502.240  ...  345032800.0   -0.173953  1.195129
# 1089  2013-09-03  493.10  500.600  ...  331928800.0   -0.916650  2.711941
#
# [1090 rows x 15 columns]

# %%
df.fillna(-99999)
# Out:
#             Date    Open     High  ...   Adj_Volume  PCT_change    HL_PCT
# 0     2017-12-28  171.00  171.850  ...   65920748.0    0.046784  0.800795
# 1     2017-12-27  170.10  170.780  ...   85992852.0    0.293945  0.627198
# 2     2017-12-26  170.80  171.470  ...  132742144.0   -0.134660  1.050009
# 3     2017-12-22  174.68  175.424  ...   65397776.0    0.188917  0.527970
# 4     2017-12-21  174.17  176.020  ...   83799584.0    0.482287  1.097080
# ...          ...     ...      ...  ...          ...         ...       ...
# 1085  2013-09-09  505.00  507.920  ...  340687200.0    0.231683  0.877176
# 1086  2013-09-06  498.44  499.380  ...  359525600.0   -0.044138  1.892738
# 1087  2013-09-05  500.25  500.680  ...  236367600.0   -0.995502  1.421447
# 1088  2013-09-04  499.56  502.240  ...  345032800.0   -0.173953  1.195129
# 1089  2013-09-03  493.10  500.600  ...  331928800.0   -0.916650  2.711941
#
# [1090 rows x 15 columns]

# %% [markdown]
# ### ***MICRO TASK 2***

# %%
import math
new=pd.DataFrame()
new= df[['Adj_Close','PCT_change','HL_PCT','Adj_Volume']]
new.fillna(value=-99999, inplace=True)
new
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
#       Adj_Close  PCT_change    HL_PCT   Adj_Volume
# 0     41.156217    0.046784  0.800795   65920748.0
# 1     41.040745    0.293945  0.627198   85992852.0
# 2     41.033528   -0.134660  1.050009  132742144.0
# 3     42.101646    0.188917  0.527970   65397776.0
# 4     42.101646    0.482287  1.097080   83799584.0
# ...         ...         ...       ...          ...
# 1085  16.033661    0.231683  0.877176  340687200.0
# 1086  15.781833   -0.044138  1.892738  359525600.0
# 1087  15.688388   -0.995502  1.421447  236367600.0
# 1088  15.796753   -0.173953  1.195129  345032800.0
# 1089  15.476472   -0.916650  2.711941  331928800.0
#
# [1090 rows x 4 columns]

# %%
var1= int(math.ceil(0.01 * len(df)))
new['label'] = df['Adj_Close'].shift(var1)
new.dropna(inplace=True)
new
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Adj_Close  PCT_change    HL_PCT   Adj_Volume      label
# 11    41.305369   -0.261400  0.541060   77636920.0  41.156217
# 12    41.538719    2.050827  2.374472  141095036.0  41.040745
# ...

# %% [markdown]
# ### ***MICRO TASK 3***

# %%
#importing the needed libraries
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
x = new[['Adj_Close','PCT_change','HL_PCT','Adj_Volume']]
x = preprocessing.scale(x)
y = new['label']
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
reg = LinearRegression()  
reg.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("INTERCEPT IS :",end=" ")
print(reg.intercept_)
print("COEFFICIENTS ARE :",end=" ")
print(reg.coef_)
# Out:
# INTERCEPT IS : 26.484074216967862
# COEFFICIENTS ARE : [ 6.39038589 -0.07724211 -0.0718394  -0.0574228 ]

# %%
score1 = reg.score(X_test, y_test)
score1
# Out:
# 0.9705177787602819

# %%
y_pred = reg.predict(x)
y_pred
# Out:
# array([41.56510453, 41.47286101, 40.97420575, ..., 16.13724416,
#        16.14997653, 15.77795058])

# %%
print("THE FIRST TEN PREDICTIONS ARE : ",end=" ")
df_1 = pd.DataFrame()
df_1['ACTUAL'] = new['label']
df_1['PREDICTED'] = y_pred
df_1.head(10)
# Out:
# THE FIRST TEN PREDICTIONS ARE :
#        ACTUAL  PREDICTED
# 11  41.156217  41.565105
# 12  41.040745  41.472861
# 13  41.033528  40.974206
# 14  42.101646  40.930271
# 15  42.101646  40.704859
# 16  41.942872  40.922425
# 17  41.988579  41.082729
# 18  42.440845  41.210802
# 19  41.851456  41.362877
# 20  41.430464  40.885153

# %%
ax1 = sns.distplot(y, hist=False, color="r", label="Actual Value of label")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values of Pred" , ax=ax1)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ***Distplots***
#
# Plotting distplot to recognize the discrepencies

# %%
sns.distplot(y_pred,kde_kws={"color": "k", "lw": 2, "label": "KDE"},
                  hist_kws={"histtype": "step", "linewidth": 3,
                            "alpha": 1, "color": "g"})
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### ***MICRO TASK 4***

# %%
a= mean_squared_error(y,y_pred) 
a
# Out:
# 1.4636655799545917
